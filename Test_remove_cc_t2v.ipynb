# %% [markdown]
# # Import libraries

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torch.utils.tensorboard import SummaryWriter
from torch.autograd import Variable

import math
import imp
import numpy as np
import os
import time
import dataprocessing as dp
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import numpy as np

from Models_remove_cc_t2v import Model_3D
from parts_cp import *
import easydict
import csv
import pandas as pd

from sklearn.metrics import accuracy_score

# %% [markdown]
# # Main Function

# %%
if __name__ == "__main__":
    # Random seed 
    # torch.backends.cudnn.deterministic = True 
    # torch.backends.cudnn.benchmark = False
    np.random.seed(0)
    random.seed(0)
    torch.manual_seed(0)

    # Arguments
    args = easydict.EasyDict({
        "startLead": 1,
        "endLead": 9,
        "gpu": 0,
        "input": 1
    })

    # Directories
    # Dataset for pretrain
    Folder = "c:/code/ENSO/ENSO_Ham/local/Train_remove_cc_t2v_1"
    dataFolder = "./local/Dataset/Ham" #"./""./"

#     # Dataset for finetuning
#     Folder = "./finetuning_3DRFB_Attention_3"
#     dataFolder = "./"
    
    SSTFile_val = dataFolder+'/godas.input.1980_2017.nc'
    SSTFile_val_label = dataFolder+'/godas.label.1980_2017.nc'

    device = torch.device('cuda:{}'.format(args.gpu) if torch.cuda.is_available() else 'cpu')
    torch.cuda.set_device(device) # change allocation of current GPU
    print ('Current cuda device ', torch.cuda.current_device()) # check

    # Set Hyper-parameters
    regularizer_rate = 0.00001  #L2 regularization
    numEpoch =  40              # No. Epoch
    learning_rate = 0.0001      # Initial Learning Rate
    n_cycles = 4                # No. cycles in Cosine Annealing
    epochs_per_cycle = math.floor(numEpoch / n_cycles)  # No. epochs for each cycle

    dr = 0.0                   # Dropout rate for Bayesian learning
    tau = 1.0                   # Weight for the batch size in regularization weight calculation (Bayesian learning)
    lengthscale = 1e-2          # Default regularization weight (L2)
    noF = 16                    # Initial No. filters
    num_layer = 256             # Feature size of 1st fully-connected layer
    num_answer = 2              # No. answers(3=3.4/ep/cp)

    ENS_Start = 0
    ENS = 1
    # loop - 1 time only
    for lead in range(args.startLead, args.endLead) :
        print('lead phase : [{}/{}]'.format(lead, args.endLead))

        # Dataset for training
        valset = dataset_times(SSTFile_val, SSTFile_val_label, lead, sstName='sst', hcName='t300', labelName='pr', noise = False)
        batch_size = len(valset) // 1                             # batch size
        reg = lengthscale**2 * (1 - dr) / (2. * batch_size * tau) # L2 regularization weight for Bayesian learning
        testloader = DataLoader(valset, batch_size = batch_size, shuffle=False)

        test_step = len(testloader)
        assemble_real_type = np.zeros((len(valset)))
        assemble_pred_type = np.zeros((len(valset)))
        assemble_pred_prop = np.zeros((len(valset), 12))

        assemble_real_nino = np.zeros((len(valset), 23))
        assemble_pred_nino = np.zeros((len(valset), 23))
        for ens in range(ENS_Start, ENS) :
            print('ensemble phase : [{}/{}]'.format(ens+1, ENS))

            model = Model_3D(2, noF, num_layer, num_answer, dr, args.input).to(device)
            model = nn.DataParallel(model, device_ids=[0,1])
            model.state_dict(torch.load('{}/train_{}_{}/train_{}_{}.pth'.format(Folder, lead, ens, lead, ens)))
            optimizer = torch.optim.Adam(model.parameters(), lr = learning_rate, weight_decay=regularizer_rate, betas=(0.9, 0.999))
            model.eval()
            
            bayesianIter = 1

            with torch.no_grad() :
                for i, (batch, ansnino, anstype, t) in enumerate(testloader):
                    batch = Variable(batch.float().cuda())
                    ansnino = Variable(ansnino.float().cuda())
                    anstype = Variable(anstype.float().cuda())
                    t = t.unsqueeze(1).float().to(device='cuda')

                    idx = batch_size*i
                    uncertaintyarry_nino = np.zeros((bayesianIter, batch_size, 23))
                    for b in range(int(bayesianIter)):
                        output = model(batch, t) # inference
                        prednino = np.squeeze(output[0], axis=2)
                        uncertaintyarry_nino[b, :, :] = prednino.cpu()

                    if ens == 0:
                        assemble_real_nino[idx:idx+batch_size, :] = ansnino.cpu().numpy()
                        anstype = torch.argmax(anstype, dim=1).cpu().numpy()
                        assemble_real_type[idx:idx+batch_size] = anstype

                    assemble_pred_nino[idx:idx+batch_size, :] += np.mean(uncertaintyarry_nino, axis=0)
                    # assemble_pred_type[idx:idx+batch_size] += np.argmax(predMean, axis = 1)

                    del batch
                    del ansnino
                    del anstype
        
        # End of ensemble
        assemble_pred_nino /= ENS
        assemble_pred_prop /= ENS
        assemble_pred_type = np.argmax(assemble_pred_prop, axis = 1)

        corr = np.zeros(23)
        for i in range(23):
            corr[i] = dp.CorrelationSkill(assemble_real_nino[:, i], assemble_pred_nino[:, i])
            print(corr[i])
            print('Save prediction: lead = {}'.format(i) )
            inputTimeSeq = assemble_real_nino.shape[0]
            dwidth = 800
            dpi = 90
            dheight = 180
            plt.figure(figsize=(dwidth/dpi, dheight/dpi))
            timeValues = np.arange(0, inputTimeSeq)
            plt.plot(timeValues, assemble_real_nino[:, i], marker='', color='blue', linewidth=1, label="Measurement")
            plt.plot(timeValues, assemble_pred_nino[:, i], marker='', color='red', linewidth=1, linestyle='dashed', label="Prediction")
            plt.savefig(Folder + f"/{ens}_NinoPred_" + str(i).zfill(6) + ".png", orientation='landscape', bbox_inches='tight')
            plt.show()
            plt.close()
        
        np.savetxt(Folder + f'/{ens}_correlation.csv',corr,delimiter=",")
        
        print('Save classification: lead = {}'.format(i) )
        plt.figure(figsize=(dwidth/dpi, dheight/dpi))
        timeValues = np.arange(0, inputTimeSeq)
        plt.plot(timeValues, assemble_real_type, marker='', color='blue', linewidth=1, label="Measurement")
        plt.plot(timeValues, assemble_pred_type, marker='', color='red', linewidth=1, linestyle='dashed', label="Prediction")
        # plt.savefig(Folder + f"/{ens}_Month_Classification" + ".png", orientation='landscape', bbox_inches='tight')
        plt.show()
        plt.close()
        accuracy = np.zeros(1)
        accuracy[0] = accuracy_score(assemble_real_type, assemble_pred_type)
        print('Accuracy = {}'.format(accuracy))
        # np.savetxt(Folder + '/accuracy.csv',accuracy,delimiter=",")


        # print(assemble_pred_nino)
        np.save("{}/lead_{}_assemble_real_nino".format(Folder, lead), assemble_real_nino) # 길이가 valset인 것이 ensemble 갯수 만큼 들어있음
        np.save("{}/lead_{}_assemble_real_type".format(Folder, lead), assemble_real_type)
        np.save("{}/lead_{}_assemble_pred_nino".format(Folder, lead), assemble_pred_nino)
        np.save("{}/lead_{}_assemble_pred_type".format(Folder, lead), assemble_pred_type)
        np.save("{}/lead_{}_assemble_pred_prop".format(Folder, lead), assemble_pred_prop)
# Out:
# Current cuda device  0
# lead phase : [1/9]
# ensemble phase : [1/1]
# 0.0408450223759431
# Save prediction: lead = 0
# -0.050343616474996335
# Save prediction: lead = 1
# -0.036246242006047265
# Save prediction: lead = 2
# -0.03258465365644731
# Save prediction: lead = 3
# 0.0962630288758821
# Save prediction: lead = 4
# 0.013581886586079178
# Save prediction: lead = 5
# -0.19264256292172757
# Save prediction: lead = 6
# 0.13842835322523805
# Save prediction: lead = 7
# -0.12757444008256177
# Save prediction: lead = 8
# 0.17821232866639014
# Save prediction: lead = 9
# 0.05505202395849098
# Save prediction: lead = 10
# -0.09700647862119575
# Save prediction: lead = 11
# -0.30818364723837854
# Save prediction: lead = 12
# -0.146856718741014
# Save prediction: lead = 13
# -0.2954797317071265
# Save prediction: lead = 14
# -0.0930613178735254
# Save prediction: lead = 15
# 0.23659701712154138
# Save prediction: lead = 16
# -0.22231557502280586
# Save prediction: lead = 17
# 0.03872391095011087
# Save prediction: lead = 18
# -0.21658593052425634
# Save prediction: lead = 19
# -0.04483484991519021
# Save prediction: lead = 20
# -0.09770850176511443
# Save prediction: lead = 21
# 0.11344931515911123
# Save prediction: lead = 22
# Save classification: lead = 22
# Accuracy = [0.08333333]
# lead phase : [2/9]
# ensemble phase : [1/1]
# 0.10070573116412894
# Save prediction: lead = 0
# -0.08708874601394863
# Save prediction: lead = 1
# -0.23116946164984672
# Save prediction: lead = 2
# -0.09631538790997891
# Save prediction: lead = 3
# 0.002445698746871066
# Save prediction: lead = 4
# -0.20843526459026931
# Save prediction: lead = 5
# -0.1529134415746462
# Save prediction: lead = 6
# -0.10585655483414678
# Save prediction: lead = 7
# 0.34910097336232626
# Save prediction: lead = 8
# 0.22224690411339576
# Save prediction: lead = 9
# 0.3187962761198279
# Save prediction: lead = 10
# -0.42219569926128303
# Save prediction: lead = 11
# 0.08256303038187035
# Save prediction: lead = 12
# 0.27451964983813165
# Save prediction: lead = 13
# 0.19110980030488242
# Save prediction: lead = 14
# 0.21658187465605475
# Save prediction: lead = 15
# 0.18933591979148987
# Save prediction: lead = 16
# -0.36702969142067543
# Save prediction: lead = 17
# 0.026023296971525462
# Save prediction: lead = 18
# -0.2238052587788719
# Save prediction: lead = 19
# -0.19378341424526815
# Save prediction: lead = 20
# -0.007826635718038658
# Save prediction: lead = 21
# 0.23539775105799302
# Save prediction: lead = 22
# Save classification: lead = 22
# Accuracy = [0.08333333]
# lead phase : [3/9]
# ensemble phase : [1/1]
# -0.1228328417268534
# Save prediction: lead = 0
# 0.14921228571918468
# Save prediction: lead = 1
# 0.14195210803788869
# Save prediction: lead = 2
# 0.14415687206294236
# Save prediction: lead = 3
# 0.12870379823737185
# Save prediction: lead = 4
# 0.1926394942668278
# Save prediction: lead = 5
# -0.29547059053514907
# Save prediction: lead = 6
# 0.3264328455890108
# Save prediction: lead = 7
# 0.1336805110179546
# Save prediction: lead = 8
# 0.18721734870372742
# Save prediction: lead = 9
# -0.4126384571559138
# Save prediction: lead = 10
# 0.32237079670880925
# Save prediction: lead = 11
# 0.3288123709439037
# Save prediction: lead = 12
# -0.1906600059620126
# Save prediction: lead = 13
# -0.29051595296539245
# Save prediction: lead = 14
# -0.3581972126142605
# Save prediction: lead = 15
# -0.03915036941108518
# Save prediction: lead = 16
# -0.15326246199661167
# Save prediction: lead = 17
# 0.1507121393599914
# Save prediction: lead = 18
# 0.09529308581523842
# Save prediction: lead = 19
# 0.04431226635038015
# Save prediction: lead = 20
# 0.0711233978153361
# Save prediction: lead = 21
# -0.011691166926576351
# Save prediction: lead = 22
# Save classification: lead = 22
# Accuracy = [0.08333333]
# lead phase : [4/9]
# ensemble phase : [1/1]
# -0.1058192906992983
# Save prediction: lead = 0
# 0.05568740212129917
# Save prediction: lead = 1
# -0.08350309021911743
# Save prediction: lead = 2
# 0.04254545487155383
# Save prediction: lead = 3
# 0.1509720553399961
# Save prediction: lead = 4
# 0.10119449293267253
# Save prediction: lead = 5
# -0.15792763840949592
# Save prediction: lead = 6
# -0.2700941555486122
# Save prediction: lead = 7
# 0.2248933600329621
# Save prediction: lead = 8
# -0.1723572036410361
# Save prediction: lead = 9
# -0.2286504944128153
# Save prediction: lead = 10
# 0.3634785832059088
# Save prediction: lead = 11
# -0.29465108811062873
# Save prediction: lead = 12
# -0.3045772021528587
# Save prediction: lead = 13
# 0.25532922378350836
# Save prediction: lead = 14
# 0.15783336639783127
# Save prediction: lead = 15
# 0.03330442656321577
# Save prediction: lead = 16
# -0.14574018167137423
# Save prediction: lead = 17
# -0.19794205592446046
# Save prediction: lead = 18
# 0.13672864183592634
# Save prediction: lead = 19
# -0.06668471603437902
# Save prediction: lead = 20
# -0.15663039709846163
# Save prediction: lead = 21
# -0.05298553473091835
# Save prediction: lead = 22
# Save classification: lead = 22
# Accuracy = [0.08333333]
# lead phase : [5/9]
# ensemble phase : [1/1]
# 0.15624752032176664
# Save prediction: lead = 0
# -0.015391563083323534
# Save prediction: lead = 1
# 0.16531779139483838
# Save prediction: lead = 2
# -0.17067421431954102
# Save prediction: lead = 3
# 0.015072455181109473
# Save prediction: lead = 4
# 0.058200045794270794
# Save prediction: lead = 5
# 0.02958999876815521
# Save prediction: lead = 6
# 0.2646762998352549
# Save prediction: lead = 7
# -0.18706714480497977
# Save prediction: lead = 8
# 0.21903170163162256
# Save prediction: lead = 9
# -0.1662207646642301
# Save prediction: lead = 10
# 0.09336943861510129
# Save prediction: lead = 11
# 0.011429970651950236
# Save prediction: lead = 12
# -0.36038683015487166
# Save prediction: lead = 13
# 0.3305708826724697
# Save prediction: lead = 14
# -0.2571053129485112
# Save prediction: lead = 15
# -0.23738776053460922
# Save prediction: lead = 16
# -0.1935013372782245
# Save prediction: lead = 17
# -0.12827838817503934
# Save prediction: lead = 18
# 0.08583947171554122
# Save prediction: lead = 19
# 0.2842133998898566
# Save prediction: lead = 20
# 0.09488415399596083
# Save prediction: lead = 21
# 0.04704982406386967
# Save prediction: lead = 22
# Save classification: lead = 22
# Accuracy = [0.08333333]
# lead phase : [6/9]
# ensemble phase : [1/1]
# 0.13595205844142363
# Save prediction: lead = 0
# 0.0792898545040104
# Save prediction: lead = 1
# 0.09520656428795322
# Save prediction: lead = 2
# -0.1506288684574679
# Save prediction: lead = 3
# 0.22256873190932183
# Save prediction: lead = 4
# 0.04463299854751915
# Save prediction: lead = 5
# 0.0030663544077067797
# Save prediction: lead = 6
# -0.12008353513155806
# Save prediction: lead = 7
# -0.17175735280873208
# Save prediction: lead = 8
# -0.11454993085766879
# Save prediction: lead = 9
# -0.3043243522426688
# Save prediction: lead = 10
# 0.2023582890351074
# Save prediction: lead = 11
# -0.2478130491706044
# Save prediction: lead = 12
# 0.09550528726057227
# Save prediction: lead = 13
# -0.13040676302799273
# Save prediction: lead = 14
# 0.19629283789008936
# Save prediction: lead = 15
# -0.1625896735397037
# Save prediction: lead = 16
# -0.22959331064713742
# Save prediction: lead = 17
# -0.045893727161472365
# Save prediction: lead = 18
# -0.14636604517403007
# Save prediction: lead = 19
# -0.1314141964408082
# Save prediction: lead = 20
# -0.12945328728375305
# Save prediction: lead = 21
# -0.15183684066951525
# Save prediction: lead = 22
# Save classification: lead = 22
# Accuracy = [0.08333333]
# lead phase : [7/9]
# ensemble phase : [1/1]
# -0.022736608695755695
# Save prediction: lead = 0
# -0.0648198570578893
# Save prediction: lead = 1
# -0.18297537092631375
# Save prediction: lead = 2
# -0.0022058243647985845
# Save prediction: lead = 3
# 0.11822945511200621
# Save prediction: lead = 4
# 0.043380261967780415
# Save prediction: lead = 5
# 0.10108439318705524
# Save prediction: lead = 6
# -0.31095676837091185
# Save prediction: lead = 7
# 0.2891112276212121
# Save prediction: lead = 8
# -0.11219878276132682
# Save prediction: lead = 9
# -0.1253672395026029
# Save prediction: lead = 10
# -0.1957343005906842
# Save prediction: lead = 11
# 0.20842775328557372
# Save prediction: lead = 12
# 0.1892321596749529
# Save prediction: lead = 13
# 0.1014368339604183
# Save prediction: lead = 14
# -0.12657189114533898
# Save prediction: lead = 15
# 0.22499325196477873
# Save prediction: lead = 16
# -0.057417937392230355
# Save prediction: lead = 17
# -0.07149564897938603
# Save prediction: lead = 18
# -0.15847358169401385
# Save prediction: lead = 19
# -0.18073360388556095
# Save prediction: lead = 20
# 0.10199904586684087
# Save prediction: lead = 21
# 0.1443673891847806
# Save prediction: lead = 22
# Save classification: lead = 22
# Accuracy = [0.08333333]
# lead phase : [8/9]
# ensemble phase : [1/1]
# -0.010495766399319803
# Save prediction: lead = 0
# -0.10402115680769548
# Save prediction: lead = 1
# -0.09442816436357704
# Save prediction: lead = 2
# 0.1143650821812548
# Save prediction: lead = 3
# 0.046426102155554906
# Save prediction: lead = 4
# 0.0003323755137017205
# Save prediction: lead = 5
# 0.2065843459398264
# Save prediction: lead = 6
# 0.2146535941138713
# Save prediction: lead = 7
# -0.12823635765538496
# Save prediction: lead = 8
# -0.24831669163989822
# Save prediction: lead = 9
# 0.21810774442119116
# Save prediction: lead = 10
# 0.08288971500732885
# Save prediction: lead = 11
# 0.02134878346968107
# Save prediction: lead = 12
# -0.2193541031279794
# Save prediction: lead = 13
# -0.012546251016262618
# Save prediction: lead = 14
# 0.20052331138522805
# Save prediction: lead = 15
# -0.2875967609013175
# Save prediction: lead = 16
# -0.1448814464396928
# Save prediction: lead = 17
# 0.17043845564333268
# Save prediction: lead = 18
# -0.1431950437465571
# Save prediction: lead = 19
# 0.023160863855813705
# Save prediction: lead = 20
# -0.06676488497742868
# Save prediction: lead = 21
# -0.1615263967635919
# Save prediction: lead = 22
# Save classification: lead = 22
# Accuracy = [0.08333333]
